# %%
import pandas as pd
import json
from matplotlib import pyplot as plt
import numpy as np
import matplotlib.pyplot as plt

# %%
rushstat = pd.read_csv('RUSHING - Sheet1.csv')
rushstat.head()
# Out:
#   No.          Player Age Pos   G  GS  Att  Yds TD  1D  YBC YBC/Att  YAC  \
# 0  34     Jerome Ford  24  RB  17  12  204  813  4  33  446     2.2  367
# 1  27     Kareem Hunt  28  RB  15   2  135  411  9  38  236     1.7  175
# 2  20   Pierre Strong  25  RB  17   1   63  291  1  10  133     2.1  158
# 3  24      Nick Chubb  28  RB   2   2   28  170  0   8  100     3.6   70
# 4   4  Deshaun Watson  28  QB   6   6   26  142  1  10   90     3.5   52
#
#   YAC/Att BrkTkl Att/Br
# 0     1.8     26    7.8
# 1     1.3      2   67.5
# 2     2.5      5   12.6
# 3     2.5      2     14
# 4       2      3    8.7

# %% [markdown]
# The rushing stats for the Cleveland Browns from the past 2 years

# %%
recstat = pd.read_csv('24RECEIVING - Sheet1 (1).csv')
recstat.head()
# Out:
#   No.          Player Age Pos   G  GS  Tgt Rec   Yds TD  ... YBC/R  YAC YAC/R  \
# 0  85    David Njoku*  27  TE  16  16  123  81   882  6  ...   3.5  599   7.4
# 1   2   Amari Cooper*  29  WR  15  15  128  72  1250  5  ...  13.6  271   3.8
# 2   8    Elijah Moore  23  WR  17  12  104  59   640  2  ...   7.6  191   3.2
# 3  34     Jerome Ford  24  RB  17  12   63  44   319  5  ...   0.3  304   6.9
# 4  19  Cedric Tillman  23  WR  14   3   44  21   224  0  ...   6.5   88   4.2
#
#    ADOT BrkTkl Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21
# 0   4.5     10         NaN         NaN         NaN         NaN         NaN
# 1  14.3      2         NaN         NaN         NaN         NaN         NaN
# 2    11      4         NaN         NaN         NaN         NaN         NaN
# 3   0.5      4         NaN         NaN         NaN         NaN         NaN
# 4  10.6      2         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# The receiving stats for the Cleveland Browns from the past 2 years

# %%
recstat
# Out:
#     No.                 Player  Age  Pos    G   GS  Tgt  Rec   Yds  TD  ...  \
# 0    85           David Njoku*   27   TE   16   16  123   81   882   6  ...
# 1     2          Amari Cooper*   29   WR   15   15  128   72  1250   5  ...
# 2     8           Elijah Moore   23   WR   17   12  104   59   640   2  ...
# 3    34            Jerome Ford   24   RB   17   12   63   44   319   5  ...
# 4    19         Cedric Tillman   23   WR   14    3   44   21   224   0  ...
# 5    84           Jordan Akins   31   TE   17    4   23   15   132   0  ...
# 6    27            Kareem Hunt   28   RB   15    2   21   15    84   0  ...
# 7    18             David Bell   23   WR   15    3   23   14   167   3  ...
# 8    88        Harrison Bryant   25   TE   17    9   20   13    81   3  ...
# 9    11  Donovan Peoples-Jones   24   WR    7    5   18    8    97   0  ...
# 10   20          Pierre Strong   25   RB   17    1    8    5    47   0  ...
# 11   24             Nick Chubb   28   RB    2    2    4    4    21   0  ...
# 12    3       Marquise Goodwin   33   WR   12    0   13    4    67   0  ...
# 13   11           James Proche   27   WR   10    1    5    0     0   0  ...
# 14  NaN             Team Total  NaN  NaN  NaN  NaN  597  355  4011  24  ...
# 15  No.                 Player  Age  Pos    G   GS  Tgt  Rec   Yds  TD  ...
# 16    3            Jerry Jeudy   25   WR   11   10   78   45   645   2  ...
# 17    8           Elijah Moore   24   WR   11    7   63   42   336   1  ...
# 18   85            David Njoku   28   TE    8    8   57   40   345   2  ...
# 19   19         Cedric Tillman   24   WR   11    6   49   29   339   3  ...
# 20   34            Jerome Ford   25   RB    9    4   31   26   126   0  ...
# 21    2           Amari Cooper   30   WR    6    6   53   24   250   2  ...
# 22   88           Jordan Akins   32   TE   11    2   34   23   229   1  ...
# 23   20          Pierre Strong   26   RB    9    0   13    7    77   0  ...
# 24   27         D'Onta Foreman   28   RB    8    2    5    5    46   0  ...
# 25   86       Blake Whiteheart   24   TE    5    0    4    4    42   1  ...
# 26   18             David Bell   24   WR    1    0    3    3    27   0  ...
# 27   24             Nick Chubb   29   RB    5    5    7    3     7   0  ...
# 28   16          Jaelon Darden   25   WR    6    1    1    1     6   0  ...
# 29   11           James Proche   28   WR    4    0    1    1     3   0  ...
# 30   84            Geoff Swaim   31   TE    8    2    1    1     7   0  ...
# 31   80          Jamari Thrash   24   WR    4    0    1    1    11   0  ...
# 32  NaN             Team Total  NaN  NaN  NaN  NaN  401  255  2496  12  ...
#
#     YBC/R   YAC  YAC/R  ADOT  BrkTkl Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 0     3.5   599    7.4   4.5      10         NaN         NaN         NaN
# 1    13.6   271    3.8  14.3       2         NaN         NaN         NaN
# 2     7.6   191    3.2    11       4         NaN         NaN         NaN
# 3     0.3   304    6.9   0.5       4         NaN         NaN         NaN
# 4     6.5    88    4.2  10.6       2         NaN         NaN         NaN
# 5     4.9    58    3.9   4.7       3         NaN         NaN         NaN
# 6    -0.9    98    6.5  -0.3       0         NaN         NaN         NaN
# 7     6.7    73    5.2   6.2       1         NaN         NaN         NaN
# 8     3.5    35    2.7   4.1       1         NaN         NaN         NaN
# 9     9.4    22    2.8  10.9       0         NaN         NaN         NaN
# 10   -5.2    73   14.6  -0.6       0         NaN         NaN         NaN
# 11    0.3    20      5   0.3       0         NaN         NaN         NaN
# 12   11.5    21    5.3  30.1       0         NaN         NaN         NaN
# 13    NaN     0    NaN  17.2       0         NaN         NaN         NaN
# 14    6.1  1853    5.2   8.4      27         NaN         NaN         NaN
# 15  YBC/R   YAC  YAC/R  ADOT  BrkTkl      Rec/Br        Drop       Drop%
# 16   10.9   153    3.4  12.6       0         NaN           5         6.4
# 17    5.9    87    2.1   8.7       1          42           3         4.8
# 18    4.1   182    4.6   4.3       2          20           4           7
# 19    8.1   104    3.6  11.1       4         7.3           3         6.1
# 20   -2.3   186    7.2    -1       6         4.3           1         3.2
# 21      8    57    2.4  12.1       1          24          10        18.9
# 22    6.3    84    3.7     6       1          23           0           0
# 23   -2.6    95   13.6  -0.2       2         3.5           2        15.4
# 24    0.8    42    8.4   0.8       1           5           0           0
# 25    9.5     4      1   9.5       0         NaN           0           0
# 26    6.3     8    2.7   6.3       0         NaN           0           0
# 27      0     7    2.3  -0.6       0         NaN           0           0
# 28     -3     9      9    -3       0         NaN           0           0
# 29     -1     4      4    -1       1           1           0           0
# 30      2     5      5     2       0         NaN           0           0
# 31      3     8      8     3       0         NaN           0           0
# 32    5.7  1035    4.1   7.9      19        13.4          28           7
#
#    Unnamed: 20 Unnamed: 21
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# 5          NaN         NaN
# 6          NaN         NaN
# 7          NaN         NaN
# 8          NaN         NaN
# 9          NaN         NaN
# 10         NaN         NaN
# 11         NaN         NaN
# 12         NaN         NaN
# 13         NaN         NaN
# 14         NaN         NaN
# 15         Int         Rat
# 16           2        82.5
# 17           4        58.7
# 18           0        97.5
# 19           2        83.6
# 20           0        83.6
# 21           1        64.2
# 22           0        96.3
# 23           0        71.6
# 24           0         105
# 25           0         150
# 26           0       104.2
# 27           0        50.3
# 28           0        91.7
# 29           0        79.2
# 30           0        95.8
# 31           0       112.5
# 32           9        81.6
#
# [33 rows x 22 columns]

# %% [markdown]
# Expanded version of receiving stats

# %%
pastat = pd.read_csv('23PASSING - Sheet1 (1).csv')
pastat.head()
# Out:
#   No.                    Player Age Pos  G GS  Cmp  Att   Yds Bats ThAwy  \
# 0  15                Joe Flacco  38  QB  5  5  123  204  1616    3     7
# 1   4            Deshaun Watson  28  QB  6  6  105  171  1115    4     5
# 2  17  Dorian Thompson-Robinson  24  QB  8  3   60  112   440    2     4
# 3  10               P.J. Walker  28  QB  6  2   54  111   674    4     3
# 4  12              Jeff Driskel  30  QB  1  1   13   26   166    2     1
#
#   Spikes Drops   Drop% BadTh    Bad% OnTgt  OnTgt%
# 0      0     9   4.60%    35  17.80%   138  70.10%
# 1      1    12   7.30%    34  20.60%   118  71.50%
# 2      2    11  10.40%    21  19.80%    74  69.80%
# 3      1     6   5.60%    32  29.90%    61  57.00%
# 4      0     4  16.00%     4  16.00%    18  72.00%

# %% [markdown]
# The passing stats for the Cleveland Browns from the past 2 years

# %%
pastat
# Out:
#    No.                    Player  Age  Pos  G  GS  Cmp  Att   Yds  Bats  \
# 0   15                Joe Flacco   38   QB  5   5  123  204  1616     3
# 1    4            Deshaun Watson   28   QB  6   6  105  171  1115     4
# 2   17  Dorian Thompson-Robinson   24   QB  8   3   60  112   440     2
# 3   10               P.J. Walker   28   QB  6   2   54  111   674     4
# 4   12              Jeff Driskel   30   QB  1   1   13   26   166     2
# 5  No.                    Player  Age  Pos  G  GS  Cmp  Att   Yds  Bats
# 6    4            Deshaun Watson   29   QB  7   7  137  216  1148     5
# 7    5            Jameis Winston   30   QB  9   4  107  172  1266     6
# 8   17  Dorian Thompson-Robinson   25   QB  3   0   11   25    82     1
#
#    ThAwy  Spikes  Drops   Drop%  BadTh    Bad%  OnTgt  OnTgt%
# 0      7       0      9   4.60%     35  17.80%    138  70.10%
# 1      5       1     12   7.30%     34  20.60%    118  71.50%
# 2      4       2     11  10.40%     21  19.80%     74  69.80%
# 3      3       1      6   5.60%     32  29.90%     61  57.00%
# 4      1       0      4  16.00%      4  16.00%     18  72.00%
# 5  ThAwy  Spikes  Drops   Drop%  BadTh    Bad%  OnTgt  OnTgt%
# 6      5       0     20   9.50%     34  16.10%    166  78.70%
# 7      1       1      6   3.50%     30  17.60%     96  56.50%
# 8      4       0      1   4.80%      3  14.30%     12  57.10%

# %% [markdown]
# The passing stats for the Cleveland Browns from the past 2 years expanded

# %%
defstat = pd.read_csv('DEFENSE - Sheet1.csv')
defstat.head()
# Out:
#   No.                    Player Age Pos   G  GS Int Tgt Cmp    Cmp%  ...  \
# 0  23            Martin Emerson  23  CB  16  12   4  79  37  46.80%  ...
# 1   0           Greg Newsome II  23  CB  14  13   2  67  38  56.70%  ...
# 2  21              Denzel Ward*  26  CB  13  11   2  66  32  48.50%  ...
# 3   6  Jeremiah Owusu-Koramoah*  24  LB  16  13   2  45  35  77.80%  ...
# 4  22              Grant Delpit  25   S  13  13   1  33  24  72.70%  ...
#
#     Rat DADOT  Air  YAC Bltz Hrry QBKD   Sk Prss Unnamed: 23
# 0  46.3  12.8  344  155    0    0    0    0    0         NaN
# 1  74.8   7.5  161  289   14    1    0  0.5    2         NaN
# 2  56.2  10.5  187  151    2    0    0    0    0         NaN
# 3  93.5   2.9   71  179   60    1    0  3.5    5         NaN
# 4  99.8   4.7   92  142   33    3    2  1.5    7         NaN
#
# [5 rows x 24 columns]

# %%
defstat
# Out:
#     No.                    Player  Age  Pos    G   GS Int  Tgt  Cmp    Cmp%  \
# 0    23            Martin Emerson   23   CB   16   12   4   79   37  46.80%
# 1     0           Greg Newsome II   23   CB   14   13   2   67   38  56.70%
# 2    21              Denzel Ward*   26   CB   13   11   2   66   32  48.50%
# 3     6  Jeremiah Owusu-Koramoah*   24   LB   16   13   2   45   35  77.80%
# 4    22              Grant Delpit   25    S   13   13   1   33   24  72.70%
# ..  ...                       ...  ...  ...  ...  ...  ..  ...  ...     ...
# 59   92                Sam Kamara   27   DE    7    0   0    0    0     NaN
# 60   51              Michael Hall   21   DT    4    0   0    0    0     NaN
# 61   52             Elerson Smith   26   LB    2    0   0    0    0     NaN
# 62   42               Tony Fields   25   LB    1    0   0    0    0     NaN
# 63  NaN                Team Total  NaN  NaN  NaN  NaN   2  307  201  62.40%
#
#     ...    Rat DADOT   Air   YAC Bltz Hrry QBKD   Sk Prss Unnamed: 23
# 0   ...   46.3  12.8   344   155    0    0    0    0    0         NaN
# 1   ...   74.8   7.5   161   289   14    1    0  0.5    2         NaN
# 2   ...   56.2  10.5   187   151    2    0    0    0    0         NaN
# 3   ...   93.5   2.9    71   179   60    1    0  3.5    5         NaN
# 4   ...   99.8   4.7    92   142   33    3    2  1.5    7         NaN
# ..  ...    ...   ...   ...   ...  ...  ...  ...  ...  ...         ...
# 59  ...    NaN   NaN     0     0    0    1    0    0    1           5
# 60  ...    NaN   NaN     0     0    1    6    2    0    8           5
# 61  ...    NaN   NaN     0     0    0    1    0    0    1           2
# 62  ...    NaN   NaN     0     0    1    0    0    0    0           2
# 63  ...  100.1  10.2  1444  1317  139   35   36   32  106         702
#
# [64 rows x 24 columns]

# %% [markdown]
# The defensive stats for the Cleveland Browns from the past 2 years

# %%
fig1, ax1 = plt.subplots(1)
ax1.hist(pastat['Yds'], bins = 4)

plt.show()

# %%
fig2, ax2 = plt.subplots()
ax2.scatter(pastat['Cmp'], pastat['Yds'])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
y =[0, 82, 166, 440, 674, 1115, 1148, 1266, 1616]
x =[0, 11, 13, 54, 60, 105, 107, 123, 137]

# %%
plt.plot(x, y)
plt.axis([0, 150, 1, 1700])

plt.show()

# %%
fig3, ax3 = plt.subplots()
ax3.scatter(pastat['OnTgt'], pastat['Cmp'])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The results that I have come up with so far show a couple correlations from the passing stats from the Browns, but passing stats are the only ones I have interpreted. With this last scatter plot comparing the On Target throws from a Quarterback and the Completions that result you can see that the more On Target throws the more completions a quarterback will have. With the scatter plot above that one comparing Completions and yards, you can see that more completions will ofc equal more yards but once we get into yards per completion and yards per attempt we will start to
