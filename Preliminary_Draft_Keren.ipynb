# %% [markdown]
# # Preliminary Draft
# ## Paul Keren
# ### 12/4/2024
# The purpose of this analysis is to figure out what the problem with the Cleveland Browns football team this year. Last season Cleveland had a record of 11-6 and made the playoffs, but this year they have a record of 3-9 and are one of the worst teams in the NFL. So my goal for this project is to find what is wrong with the Browns this year. The main question is why is this team so bad with the same very good talent. The motivation comes from being a Cleveland sports fan and seeing other professional Cleveland teams succeeding, and knowing that it is possible to be a good team.
#
# The starting point for me came from watching the Browns every week and getting super frustrated every week. The Browns returned most of their talent from a successful 2023 campaign so I was not sure where the problem was. There aren't any others I am following in this analysis.

# %%
import urllib
import requests
import pandas as pd
import json
import base64
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np

# %%
rushstat = pd.read_csv('RUSHING - Sheet1.csv')
rushstat.head()
# Out:
#   No.          Player Age Pos   G  GS  Att  Yds TD  1D  YBC YBC/Att  YAC  \
# 0  34     Jerome Ford  24  RB  17  12  204  813  4  33  446     2.2  367
# 1  27     Kareem Hunt  28  RB  15   2  135  411  9  38  236     1.7  175
# 2  20   Pierre Strong  25  RB  17   1   63  291  1  10  133     2.1  158
# 3  24      Nick Chubb  28  RB   2   2   28  170  0   8  100     3.6   70
# 4   4  Deshaun Watson  28  QB   6   6   26  142  1  10   90     3.5   52
#
#   YAC/Att BrkTkl Att/Br
# 0     1.8     26    7.8
# 1     1.3      2   67.5
# 2     2.5      5   12.6
# 3     2.5      2     14
# 4       2      3    8.7

# %% [markdown]
# The rushing stats for the Cleveland Browns from the past 2 years from www.pro-football-reference.com

# %%
recstat = pd.read_csv('24RECEIVING - Sheet1 (1).csv')
recstat.head()
# Out:
#   No.          Player Age Pos   G  GS  Tgt Rec   Yds TD  ... YBC/R  YAC YAC/R  \
# 0  85    David Njoku*  27  TE  16  16  123  81   882  6  ...   3.5  599   7.4
# 1   2   Amari Cooper*  29  WR  15  15  128  72  1250  5  ...  13.6  271   3.8
# 2   8    Elijah Moore  23  WR  17  12  104  59   640  2  ...   7.6  191   3.2
# 3  34     Jerome Ford  24  RB  17  12   63  44   319  5  ...   0.3  304   6.9
# 4  19  Cedric Tillman  23  WR  14   3   44  21   224  0  ...   6.5   88   4.2
#
#    ADOT BrkTkl Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20 Unnamed: 21
# 0   4.5     10         NaN         NaN         NaN         NaN         NaN
# 1  14.3      2         NaN         NaN         NaN         NaN         NaN
# 2    11      4         NaN         NaN         NaN         NaN         NaN
# 3   0.5      4         NaN         NaN         NaN         NaN         NaN
# 4  10.6      2         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# The receiving stats for the Cleveland Browns from the past 2 years from www.pro-football-reference.com

# %%
recstat
# Out:
#     No.                 Player  Age  Pos    G   GS  Tgt  Rec   Yds  TD  ...  \
# 0    85           David Njoku*   27   TE   16   16  123   81   882   6  ...
# 1     2          Amari Cooper*   29   WR   15   15  128   72  1250   5  ...
# 2     8           Elijah Moore   23   WR   17   12  104   59   640   2  ...
# 3    34            Jerome Ford   24   RB   17   12   63   44   319   5  ...
# 4    19         Cedric Tillman   23   WR   14    3   44   21   224   0  ...
# 5    84           Jordan Akins   31   TE   17    4   23   15   132   0  ...
# 6    27            Kareem Hunt   28   RB   15    2   21   15    84   0  ...
# 7    18             David Bell   23   WR   15    3   23   14   167   3  ...
# 8    88        Harrison Bryant   25   TE   17    9   20   13    81   3  ...
# 9    11  Donovan Peoples-Jones   24   WR    7    5   18    8    97   0  ...
# 10   20          Pierre Strong   25   RB   17    1    8    5    47   0  ...
# 11   24             Nick Chubb   28   RB    2    2    4    4    21   0  ...
# 12    3       Marquise Goodwin   33   WR   12    0   13    4    67   0  ...
# 13   11           James Proche   27   WR   10    1    5    0     0   0  ...
# 14  NaN             Team Total  NaN  NaN  NaN  NaN  597  355  4011  24  ...
# 15  No.                 Player  Age  Pos    G   GS  Tgt  Rec   Yds  TD  ...
# 16    3            Jerry Jeudy   25   WR   11   10   78   45   645   2  ...
# 17    8           Elijah Moore   24   WR   11    7   63   42   336   1  ...
# 18   85            David Njoku   28   TE    8    8   57   40   345   2  ...
# 19   19         Cedric Tillman   24   WR   11    6   49   29   339   3  ...
# 20   34            Jerome Ford   25   RB    9    4   31   26   126   0  ...
# 21    2           Amari Cooper   30   WR    6    6   53   24   250   2  ...
# 22   88           Jordan Akins   32   TE   11    2   34   23   229   1  ...
# 23   20          Pierre Strong   26   RB    9    0   13    7    77   0  ...
# 24   27         D'Onta Foreman   28   RB    8    2    5    5    46   0  ...
# 25   86       Blake Whiteheart   24   TE    5    0    4    4    42   1  ...
# 26   18             David Bell   24   WR    1    0    3    3    27   0  ...
# 27   24             Nick Chubb   29   RB    5    5    7    3     7   0  ...
# 28   16          Jaelon Darden   25   WR    6    1    1    1     6   0  ...
# 29   11           James Proche   28   WR    4    0    1    1     3   0  ...
# 30   84            Geoff Swaim   31   TE    8    2    1    1     7   0  ...
# 31   80          Jamari Thrash   24   WR    4    0    1    1    11   0  ...
# 32  NaN             Team Total  NaN  NaN  NaN  NaN  401  255  2496  12  ...
#
#     YBC/R   YAC  YAC/R  ADOT  BrkTkl Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 0     3.5   599    7.4   4.5      10         NaN         NaN         NaN
# 1    13.6   271    3.8  14.3       2         NaN         NaN         NaN
# 2     7.6   191    3.2    11       4         NaN         NaN         NaN
# 3     0.3   304    6.9   0.5       4         NaN         NaN         NaN
# 4     6.5    88    4.2  10.6       2         NaN         NaN         NaN
# 5     4.9    58    3.9   4.7       3         NaN         NaN         NaN
# 6    -0.9    98    6.5  -0.3       0         NaN         NaN         NaN
# 7     6.7    73    5.2   6.2       1         NaN         NaN         NaN
# 8     3.5    35    2.7   4.1       1         NaN         NaN         NaN
# 9     9.4    22    2.8  10.9       0         NaN         NaN         NaN
# 10   -5.2    73   14.6  -0.6       0         NaN         NaN         NaN
# 11    0.3    20      5   0.3       0         NaN         NaN         NaN
# 12   11.5    21    5.3  30.1       0         NaN         NaN         NaN
# 13    NaN     0    NaN  17.2       0         NaN         NaN         NaN
# 14    6.1  1853    5.2   8.4      27         NaN         NaN         NaN
# 15  YBC/R   YAC  YAC/R  ADOT  BrkTkl      Rec/Br        Drop       Drop%
# 16   10.9   153    3.4  12.6       0         NaN           5         6.4
# 17    5.9    87    2.1   8.7       1          42           3         4.8
# 18    4.1   182    4.6   4.3       2          20           4           7
# 19    8.1   104    3.6  11.1       4         7.3           3         6.1
# 20   -2.3   186    7.2    -1       6         4.3           1         3.2
# 21      8    57    2.4  12.1       1          24          10        18.9
# 22    6.3    84    3.7     6       1          23           0           0
# 23   -2.6    95   13.6  -0.2       2         3.5           2        15.4
# 24    0.8    42    8.4   0.8       1           5           0           0
# 25    9.5     4      1   9.5       0         NaN           0           0
# 26    6.3     8    2.7   6.3       0         NaN           0           0
# 27      0     7    2.3  -0.6       0         NaN           0           0
# 28     -3     9      9    -3       0         NaN           0           0
# 29     -1     4      4    -1       1           1           0           0
# 30      2     5      5     2       0         NaN           0           0
# 31      3     8      8     3       0         NaN           0           0
# 32    5.7  1035    4.1   7.9      19        13.4          28           7
#
#    Unnamed: 20 Unnamed: 21
# 0          NaN         NaN
# 1          NaN         NaN
# 2          NaN         NaN
# 3          NaN         NaN
# 4          NaN         NaN
# 5          NaN         NaN
# 6          NaN         NaN
# 7          NaN         NaN
# 8          NaN         NaN
# 9          NaN         NaN
# 10         NaN         NaN
# 11         NaN         NaN
# 12         NaN         NaN
# 13         NaN         NaN
# 14         NaN         NaN
# 15         Int         Rat
# 16           2        82.5
# 17           4        58.7
# 18           0        97.5
# 19           2        83.6
# 20           0        83.6
# 21           1        64.2
# 22           0        96.3
# 23           0        71.6
# 24           0         105
# 25           0         150
# 26           0       104.2
# 27           0        50.3
# 28           0        91.7
# 29           0        79.2
# 30           0        95.8
# 31           0       112.5
# 32           9        81.6
#
# [33 rows x 22 columns]

# %% [markdown]
# Expanded version of receiving stats

# %%
pastat = pd.read_csv('23PASSING - Sheet1 (1).csv')
pastat.head()
# Out:
#   No.                    Player Age Pos  G GS  Cmp  Att   Yds Bats ThAwy  \
# 0  15                Joe Flacco  38  QB  5  5  123  204  1616    3     7
# 1   4            Deshaun Watson  28  QB  6  6  105  171  1115    4     5
# 2  17  Dorian Thompson-Robinson  24  QB  8  3   60  112   440    2     4
# 3  10               P.J. Walker  28  QB  6  2   54  111   674    4     3
# 4  12              Jeff Driskel  30  QB  1  1   13   26   166    2     1
#
#   Spikes Drops   Drop% BadTh    Bad% OnTgt  OnTgt%
# 0      0     9   4.60%    35  17.80%   138  70.10%
# 1      1    12   7.30%    34  20.60%   118  71.50%
# 2      2    11  10.40%    21  19.80%    74  69.80%
# 3      1     6   5.60%    32  29.90%    61  57.00%
# 4      0     4  16.00%     4  16.00%    18  72.00%

# %% [markdown]
# The passing stats for the Cleveland Browns from the past 2 years from www.pro-football-reference.com.

# %%
pastat
# Out:
#    No.                    Player  Age  Pos  G  GS  Cmp  Att   Yds  Bats  \
# 0   15                Joe Flacco   38   QB  5   5  123  204  1616     3
# 1    4            Deshaun Watson   28   QB  6   6  105  171  1115     4
# 2   17  Dorian Thompson-Robinson   24   QB  8   3   60  112   440     2
# 3   10               P.J. Walker   28   QB  6   2   54  111   674     4
# 4   12              Jeff Driskel   30   QB  1   1   13   26   166     2
# 5  No.                    Player  Age  Pos  G  GS  Cmp  Att   Yds  Bats
# 6    4            Deshaun Watson   29   QB  7   7  137  216  1148     5
# 7    5            Jameis Winston   30   QB  9   4  107  172  1266     6
# 8   17  Dorian Thompson-Robinson   25   QB  3   0   11   25    82     1
#
#    ThAwy  Spikes  Drops   Drop%  BadTh    Bad%  OnTgt  OnTgt%
# 0      7       0      9   4.60%     35  17.80%    138  70.10%
# 1      5       1     12   7.30%     34  20.60%    118  71.50%
# 2      4       2     11  10.40%     21  19.80%     74  69.80%
# 3      3       1      6   5.60%     32  29.90%     61  57.00%
# 4      1       0      4  16.00%      4  16.00%     18  72.00%
# 5  ThAwy  Spikes  Drops   Drop%  BadTh    Bad%  OnTgt  OnTgt%
# 6      5       0     20   9.50%     34  16.10%    166  78.70%
# 7      1       1      6   3.50%     30  17.60%     96  56.50%
# 8      4       0      1   4.80%      3  14.30%     12  57.10%

# %% [markdown]
# The passing stats for the Cleveland Browns from the past 2 years expanded

# %%
defstat = pd.read_csv('DEFENSE - Sheet1.csv')
defstat.head()
# Out:
#   No.                    Player Age Pos   G  GS Int Tgt Cmp    Cmp%  ...  \
# 0  23            Martin Emerson  23  CB  16  12   4  79  37  46.80%  ...
# 1   0           Greg Newsome II  23  CB  14  13   2  67  38  56.70%  ...
# 2  21              Denzel Ward*  26  CB  13  11   2  66  32  48.50%  ...
# 3   6  Jeremiah Owusu-Koramoah*  24  LB  16  13   2  45  35  77.80%  ...
# 4  22              Grant Delpit  25   S  13  13   1  33  24  72.70%  ...
#
#     Rat DADOT  Air  YAC Bltz Hrry QBKD   Sk Prss Unnamed: 23
# 0  46.3  12.8  344  155    0    0    0    0    0         NaN
# 1  74.8   7.5  161  289   14    1    0  0.5    2         NaN
# 2  56.2  10.5  187  151    2    0    0    0    0         NaN
# 3  93.5   2.9   71  179   60    1    0  3.5    5         NaN
# 4  99.8   4.7   92  142   33    3    2  1.5    7         NaN
#
# [5 rows x 24 columns]

# %%
defstat
# Out:
#     No.                    Player  Age  Pos    G   GS Int  Tgt  Cmp    Cmp%  \
# 0    23            Martin Emerson   23   CB   16   12   4   79   37  46.80%
# 1     0           Greg Newsome II   23   CB   14   13   2   67   38  56.70%
# 2    21              Denzel Ward*   26   CB   13   11   2   66   32  48.50%
# 3     6  Jeremiah Owusu-Koramoah*   24   LB   16   13   2   45   35  77.80%
# 4    22              Grant Delpit   25    S   13   13   1   33   24  72.70%
# ..  ...                       ...  ...  ...  ...  ...  ..  ...  ...     ...
# 59   92                Sam Kamara   27   DE    7    0   0    0    0     NaN
# 60   51              Michael Hall   21   DT    4    0   0    0    0     NaN
# 61   52             Elerson Smith   26   LB    2    0   0    0    0     NaN
# 62   42               Tony Fields   25   LB    1    0   0    0    0     NaN
# 63  NaN                Team Total  NaN  NaN  NaN  NaN   2  307  201  62.40%
#
#     ...    Rat DADOT   Air   YAC Bltz Hrry QBKD   Sk Prss Unnamed: 23
# 0   ...   46.3  12.8   344   155    0    0    0    0    0         NaN
# 1   ...   74.8   7.5   161   289   14    1    0  0.5    2         NaN
# 2   ...   56.2  10.5   187   151    2    0    0    0    0         NaN
# 3   ...   93.5   2.9    71   179   60    1    0  3.5    5         NaN
# 4   ...   99.8   4.7    92   142   33    3    2  1.5    7         NaN
# ..  ...    ...   ...   ...   ...  ...  ...  ...  ...  ...         ...
# 59  ...    NaN   NaN     0     0    0    1    0    0    1           5
# 60  ...    NaN   NaN     0     0    1    6    2    0    8           5
# 61  ...    NaN   NaN     0     0    0    1    0    0    1           2
# 62  ...    NaN   NaN     0     0    1    0    0    0    0           2
# 63  ...  100.1  10.2  1444  1317  139   35   36   32  106         702
#
# [64 rows x 24 columns]

# %% [markdown]
# The defensive stats for the Cleveland Browns from the past 2 years from www.pro-football-reference.com.

# %%
fig1, ax1 = plt.subplots(1)
ax1.hist(pastat['Yds'], bins = 7)

plt.show()

# %%
fig2, ax2 = plt.subplots()
ax2.scatter(pastat['Cmp'], pastat['Yds'])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
y =[0, 82, 166, 440, 674, 1115, 1148, 1266, 1616]
x =[0, 11, 13, 54, 60, 105, 107, 123, 137]

# %%
plt.plot(x, y)
plt.axis([0, 150, 1, 1700])

plt.show()

# %%
fig3, ax3 = plt.subplots()
ax3.scatter(pastat['OnTgt'], pastat['Cmp'])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# The results that I have come up with so far show a couple correlations from the passing stats from the Browns, but passing stats are the only ones I have interpreted. With this last scatter plot comparing the On Target throws from a Quarterback and the Completions that result you can see that the more On Target throws the more completions a quarterback will have. With the scatter plot above that one comparing Completions and yards, you can see that more completions will ofc equal more yards but once we get into yards per completion and yards per attempt we will start to see some deciphering data.

# %% [markdown]
# The plan moving forward is to dive into each one of these main stats from the past 2 years is analyze what is different or what stands out. Then to look into that data and see what the cause is to figure out why the Browns are bad.

# %%
labels = 'Cooper', 'Njoku', 'Moore', 'Ford', 'Tillman', 'Bell'
sizes = [1250, 882, 640, 319, 224, 167]

# %%
fig4, ax4 = plt.subplots()
ax4.pie(sizes, labels=labels, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1687677d0>,
#   <matplotlib.patches.Wedge at 0x168745670>,
#   <matplotlib.patches.Wedge at 0x168767e30>,
#   <matplotlib.patches.Wedge at 0x168798440>,
#   <matplotlib.patches.Wedge at 0x1687988f0>,
#   <matplotlib.patches.Wedge at 0x168798fb0>],
#  [Text(0.4715158261458979, 0.9938172999570654, 'Cooper'),
#   Text(-1.0955258526791118, 0.09911158414486755, 'Njoku'),
#   Text(-0.3122424426125966, -1.0547533631287076, 'Moore'),
#   Text(0.6004617642649421, -0.9216537688610801, 'Ford'),
#   Text(0.9635162856363056, -0.5306942314681942, 'Tillman'),
#   Text(1.0875371844716581, -0.16511472493832435, 'Bell')],
#  [Text(0.25719045062503515, 0.5420821636129447, '35.9%'),
#   Text(-0.5975595560067882, 0.05406086407901866, '25.3%'),
#   Text(-0.17031405960687085, -0.5753200162520223, '18.4%'),
#   Text(0.32752459868996836, -0.5027202375605891, '9.2%'),
#   Text(0.525554337619803, -0.2894695808008332, '6.4%'),
#   Text(0.5932021006209044, -0.09006257723908599, '4.8%')])

# %% [markdown]
# The chart above shows the distribution of receiving yards for the Browns in 2023.

# %%
labels = 'Jeudy', 'Moore', 'Njoku', 'Tillman', 'Cooper (6 games)', 'Akins'
sizes = [880, 447, 397, 339, 250, 229]

# %%
fig5, ax5 = plt.subplots()
ax5.pie(sizes, labels=labels, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x16862e180>,
#   <matplotlib.patches.Wedge at 0x16872ea50>,
#   <matplotlib.patches.Wedge at 0x1686c9100>,
#   <matplotlib.patches.Wedge at 0x1686ca6f0>,
#   <matplotlib.patches.Wedge at 0x1686cbbc0>,
#   <matplotlib.patches.Wedge at 0x1686c9880>],
#  [Text(0.5111028983762947, 0.9740502180438907, 'Jeudy'),
#   Text(-1.007063018944671, 0.44252014177215215, 'Moore'),
#   Text(-0.8894390309267702, -0.6472234623868699, 'Njoku'),
#   Text(-0.035339942596997805, -1.0994321663737336, 'Tillman'),
#   Text(0.705097354390049, -0.8442971756627841, 'Cooper (6 games)'),
#   Text(1.056239585103715, -0.3071773736132469, 'Akins')],
#  [Text(0.2787833991143426, 0.5313001189330312, '34.6%'),
#   Text(-0.5493071012425477, 0.24137462278481023, '17.6%'),
#   Text(-0.48514856232369274, -0.3530309794837472, '15.6%'),
#   Text(-0.01927633232563516, -0.599690272567491, '13.3%'),
#   Text(0.3845985569400267, -0.46052573217970033, '9.8%'),
#   Text(0.5761306827838445, -0.16755129469813462, '9.0%')])

# %% [markdown]
# This pie chart shows the recieving yards for the Browns in 2024.
#
# Conclusion from this is that after trading away Cooper 6 games into the season other recievers have stepped in like Jeudy or Tillman but Njoku has not been as effective.

# %%
teamstat = pd.read_csv('BROWNS_TEAM - Sheet1.csv')
teamstat.head()
# Out:
#   Overall Statistics\n CLE Offense  Value (rank)      CLE Defense  \
# 0                      Points/Game    18.2 (#29)  Opp Points/Game
# 1                       Yards/Game   314.1 (#22)   Opp Yards/Game
# 2                      Points/Play   0.274 (#31)  Opp Points/Play
# 3                       Yards/Play     4.7 (#29)   Opp Yards/Play
# 4                  3D Conversion %  29.24% (#32)    Opp 3D Conv %
#
#   Value (rank).1
# 0     25.7 (#26)
# 1    349.6 (#24)
# 2    0.426 (#27)
# 3      5.8 (#30)
# 4   35.26% (#12)

# %%
teamstat
# Out:
#       Overall Statistics\n CLE Offense                      Value (rank)  \
# 0                          Points/Game                        18.2 (#29)
# 1                           Yards/Game                       314.1 (#22)
# 2                          Points/Play                       0.274 (#31)
# 3                           Yards/Play                         4.7 (#29)
# 4                      3D Conversion %                      29.24% (#32)
# 5                      4D Conversion %                       66.67% (#6)
# 6                    RZ Scoring % (TD)                       60.00% (#7)
# 7                             TDs/Game                         2.0 (#25)
# 8     Rushing Statistics\n CLE Offense                      Value (rank)
# 9                          Rush Play %                      34.47% (#31)
# 10                          Yards/Rush                         3.8 (#30)
# 11                         Rushes/Game                        22.8 (#27)
# 12                     Rush Yards/Game                        87.3 (#30)
# 13    Passing Statistics\n CLE Offense                      Value (rank)
# 14                         Pass Play %                       65.53% (#2)
# 15                        Completion %                      61.36% (#30)
# 16                          Yards/Pass                         6.4 (#26)
# 17                         Passes/Game                         39.3 (#2)
# 18                     Pass Yards/Game                       226.8 (#13)
# 19                        Int Thrown %                       2.55% (#19)
# 20                         QB Sacked %                       9.60% (#30)
# 21                  Kicking Statistics                               NaN
# 22                         CLE Offense          Value (rank) CLE Defense
# 23                     FG Conversion %        69.57% (#31) Opp FG Conv %
# 24                Turnovers Statistics                               NaN
# 25                         CLE Offense          Value (rank) CLE Defense
# 26                      TO Margin/Game     -0.7 (#28) Opp TO Margin/Game
# 27                      Giveaways/Game          1.5 (#25) Takeaways/Game
# 28                      Takeaways/Game          0.8 (#26) Giveaways/Game
# 29                        Int Thrown %      2.55% (#19) Opp Int Thrown %
# 30  Penalties Statistics\n CLE Offense          Value (rank) CLE Defense
# 31                      Penalties/Play     0.06 (#26) Opp Penalties/Play
# 32                      Penalties/Game      7.3 (#26) Opp Penalties/Game
# 33                    Penalty Yds/Game   53.7 (#22) Opp Penalty Yds/Game
# 34                     Penalty Yds/Pen      7.4 (#5) Opp Penalty Yds/Pen
# 35      Other Statistics\n CLE Offense          Value (rank) CLE Defense
# 36                     TOP % (excl OT)  51.17% (#11) Opp TOP % (excl OT)
#
#               CLE Defense Value (rank).1
# 0         Opp Points/Game     25.7 (#26)
# 1          Opp Yards/Game    349.6 (#24)
# 2         Opp Points/Play    0.426 (#27)
# 3          Opp Yards/Play      5.8 (#30)
# 4           Opp 3D Conv %   35.26% (#12)
# 5           Opp 4D Conv %   61.54% (#19)
# 6   Opp RZ Scoring % (TD)   61.11% (#24)
# 7            Opp TDs/Game      3.1 (#27)
# 8             CLE Defense   Value (rank)
# 9         Opp Rush Play %   46.20% (#23)
# 10         Opp Yards/Rush      4.6 (#22)
# 11        Opp Rushes/Game     27.8 (#21)
# 12    Opp Rush Yards/Game    128.6 (#23)
# 13            CLE Defense   Value (rank)
# 14        Opp Pass Play %   53.80% (#10)
# 15       Opp Completion %    61.34% (#4)
# 16         Opp Yards/Pass      8.0 (#31)
# 17        Opp Passes/Game      29.8 (#6)
# 18    Opp Pass Yards/Game    221.0 (#20)
# 19       Opp Int Thrown %    1.12% (#28)
# 20                 Sack %     8.23% (#8)
# 21                    NaN            NaN
# 22                    NaN   Value (rank)
# 23                    NaN    70.83% (#3)
# 24                    NaN            NaN
# 25                    NaN   Value (rank)
# 26                    NaN        #ERROR!
# 27                    NaN      0.8 (#26)
# 28                    NaN      1.5 (#25)
# 29                    NaN    1.12% (#28)
# 30                    NaN   Value (rank)
# 31                    NaN     0.05 (#23)
# 32                    NaN      6.0 (#21)
# 33                    NaN     48.9 (#20)
# 34                    NaN      8.2 (#13)
# 35                    NaN   Value (rank)
# 36                    NaN   48.83% (#11)

# %% [markdown]
# The stats above show the Browns team stats and where they rank in the national football league this season from www.teamrankings.com.

# %%
teamstat23 = pd.read_csv('BROWNS_TEAM24 - Sheet1.csv')

teamstat23.head()
# Out:
#   Overall Statistics\n  CLE Offense  Value (rank)      CLE Defense  \
# 0                       Points/Game    23.3 (#10)  Opp Points/Game
# 1                        Yards/Game   335.9 (#16)   Opp Yards/Game
# 2                       Points/Play   0.326 (#21)  Opp Points/Play
# 3                        Yards/Play     4.8 (#28)   Opp Yards/Play
# 4                   3D Conversion %  32.46% (#29)    Opp 3D Conv %
#
#   Value (rank).1
# 0     22.6 (#26)
# 1     274.9 (#1)
# 2    0.388 (#27)
# 3       4.7 (#4)
# 4    28.99% (#1)

# %%
teamstat23
# Out:
#       Overall Statistics\n  CLE Offense                      Value (rank)  \
# 0                           Points/Game                        23.3 (#10)
# 1                            Yards/Game                       335.9 (#16)
# 2                           Points/Play                       0.326 (#21)
# 3                            Yards/Play                         4.8 (#28)
# 4                       3D Conversion %                      32.46% (#29)
# 5                       4D Conversion %                      50.00% (#16)
# 6                     RZ Scoring % (TD)                      57.69% (#13)
# 7                              TDs/Game                         2.4 (#13)
# 8     Rushing Statistics\n  CLE Offense                      Value (rank)
# 9                           Rush Play %                      42.80% (#17)
# 10                           Yards/Rush                         3.9 (#26)
# 11                          Rushes/Game                         29.9 (#5)
# 12                      Rush Yards/Game                       115.2 (#13)
# 13    Passing Statistics\n  CLE Offense                      Value (rank)
# 14                          Pass Play %                      57.20% (#16)
# 15                         Completion %                      58.06% (#32)
# 16                           Yards/Pass                         6.4 (#28)
# 17                          Passes/Game                         37.2 (#4)
# 18                      Pass Yards/Game                       220.1 (#18)
# 19                         Int Thrown %                       3.73% (#31)
# 20                          QB Sacked %                       6.82% (#18)
# 21                   Kicking Statistics                               NaN
# 22                          CLE Offense          Value (rank) CLE Defense
# 23                      FG Conversion %                      91.89% (#9)
# 24                 Turnovers Statistics                               NaN
# 25                          CLE Offense                      Value (rank)
# 26                       TO Margin/Game                       -0.6 (#28)
# 27                       Giveaways/Game                        2.2 (#32)
# 28                       Takeaways/Game          0.8 (#26) Giveaways/Game
# 29                         Int Thrown %      2.55% (#19) Opp Int Thrown %
# 30  Penalties Statistics\n  CLE Offense          Value (rank) CLE Defense
# 31                       Penalties/Play     0.06 (#26) Opp Penalties/Play
# 32                       Penalties/Game      7.3 (#26) Opp Penalties/Game
# 33                     Penalty Yds/Game   53.7 (#22) Opp Penalty Yds/Game
# 34                      Penalty Yds/Pen      7.4 (#5) Opp Penalty Yds/Pen
# 35      Other Statistics\n  CLE Offense          Value (rank) CLE Defense
# 36                      TOP % (excl OT)  51.17% (#11) Opp TOP % (excl OT)
#
#               CLE Defense Value (rank).1
# 0         Opp Points/Game     22.6 (#26)
# 1          Opp Yards/Game     274.9 (#1)
# 2         Opp Points/Play    0.388 (#27)
# 3          Opp Yards/Play       4.7 (#4)
# 4           Opp 3D Conv %    28.99% (#1)
# 5           Opp 4D Conv %    40.00% (#1)
# 6   Opp RZ Scoring % (TD)   71.11% (#32)
# 7            Opp TDs/Game      2.8 (#26)
# 8             CLE Defense   Value (rank)
# 9         Opp Rush Play %   42.18% (#14)
# 10         Opp Yards/Rush      4.2 (#18)
# 11        Opp Rushes/Game      24.6 (#8)
# 12    Opp Rush Yards/Game    103.8 (#10)
# 13            CLE Defense   Value (rank)
# 14        Opp Pass Play %   57.82% (#19)
# 15       Opp Completion %    58.17% (#1)
# 16         Opp Yards/Pass       5.5 (#4)
# 17        Opp Passes/Game      30.9 (#5)
# 18    Opp Pass Yards/Game     171.1 (#2)
# 19       Opp Int Thrown %     3.23% (#4)
# 20                 Sack %     8.09% (#6)
# 21                    NaN            NaN
# 22                    NaN   Value (rank)
# 23          Opp FG Conv %    72.00% (#1)
# 24                    NaN            NaN
# 25            CLE Defense   Value (rank)
# 26     Opp TO Margin/Game            NaN
# 27         Takeaways/Game       1.6 (#9)
# 28                    NaN      1.5 (#25)
# 29                    NaN    1.12% (#28)
# 30                    NaN   Value (rank)
# 31                    NaN     0.05 (#23)
# 32                    NaN      6.0 (#21)
# 33                    NaN     48.9 (#20)
# 34                    NaN      8.2 (#13)
# 35                    NaN   Value (rank)
# 36                    NaN   48.83% (#11)

# %% [markdown]
# The stats above show the Browns team stats and where they rank in the national football league in the 2023 season from www.teamrankings.com.

# %%
team23 = ["#1", "#4", "#1", "#1", "#2", "#4"]
team24 = ["#24", "#30", "#12", "#4", "#20", "#28"]
activity = ["OPP/YPG", "OPP/YPP", "OPP/3D%", "OPP/CMP%", "OPP/PYG", "OPP/INT%"]

fig, ax = plt.subplots()
ax.plot(activity, team23, label="team23")
ax.plot(activity, team24, label="team24")
ax.legend()

plt.show()

# %% [markdown]
# The plot above shows the comparison of the Browns defense in some critical stats such as: Opponent Yards per game(OPP/YPG), Opponent yards per play(OPP/YPP), Opponent 3rd Down Conversation percentage(OPP/3D%), Opponent Completion percentage(OPP/CMP%), Opponent passing yards per game(OPP/PYG), and Opponent interception percentage(OPP/INT%). The y-axis of the graph shows the rank in the National Football league in the corresponding year. team23 is the 2023 team and 24team is the 2024 team.
#
# What we can take from this graph is that data we were focusing on before might not be as telling as this graph. This graph shows just some defensive stats, but you can take away that defense in 2023 was extremely more impressive and ranked high as number 1 in 3 of the 6 categories.

# %%
team23 = ["#10", "#16", "#13", "#13", "#17", "#18"]
team24 = ["#29", "#22", "#25", "#30", "#31", "#13"]
activity = ["PPG", "YPG", "TDS/G", "RYG", "RP%", "PYG"]

fig, ax = plt.subplots()
ax.plot(activity, team23, label="team23")
ax.plot(activity, team24, label="team24")
ax.legend()

plt.show()

# %% [markdown]
# The plot above shows the comparison of the Browns offense in stats such as: Points per game(PPG), Yards per game(YPG), Touchdowns per game(TDS/G), Rush yards per game(RYG), Rush play percentage(RP%), and Pass yards per game (PYG). team23 is the 2023 team and 24team is the 2024 team.
#
# What we can take away from this graph is that it shows that the team in 2023 was ranked higher in every category except passing yards per game.

# %% [markdown]
# From how my data has been shown with multiple and different types of graphs, the early conclusion I have come to is that the problem with the Browns may not be on the quarterbacks or the offense after all. From examing the data it is obvious in the Defense chart that the highly accomplished defense of 2023 has taken a large step back. The Browns were rated as the best defense in the NFL in 3 of those categories inlcuding: Opponent Yards per game, Opponent 3rd Down Conversation percentage, and Opponent Completion percentage. In 2024 the Browns fell back to #24, #12, and #4 in those categories. The fall from 1 to 4 is slight but the overall regression is undeniable.
#
# On the offensive standpoint there is also lots of drop-off in stats such as points per game and the rushing attack with rush yards per game down and the percentage of rush plays also down. The pass yards is now flipped but we can figure out that's from not being able to run the ball.
#
# The rushing attack the takeways on defense are my main concern though, last season Cleveland was getting an interception on 3.23% of plays and that ranked number 4 in the NFL, this season is only getting interceptions on 1.12% of plays ranking at number 28 in a league of 32. The rushing attack is another concern as we can see on the chart above that passing the ball is not a problem this year.
#
# You might be able to atrribute some of the lack of rushing to their offensive line coach leaving in the offseason and their running backs coach also leaving. The Browns have a problem running the ball, when they can't run the ball they run a lot less, which leads to them passing the ball and taking less time off the clock. From teamrankings.com - The Browns lead the league in time of possession last season at 32:29 per game, this season though they fall back down the number 11 with 30:42 per game. Even though that is not a large slide the combination of less points per game, less yards, and less time with the ball the worse you are going to be. With the defense not getting takeaways very much this season, they are not there to bail out the extremely subpar offense.
